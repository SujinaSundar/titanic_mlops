# %%
import pandas as pd

df = pd.read_csv("data/titanic.csv")
df.head()
# Out:
#    Pclass  Sex   Age   Fare  Survived
# 0       3    0  22.0   7.25         0
# 1       1    1  38.0  71.28         1
# 2       3    1  26.0   7.92         1
# 3       1    1  35.0  53.10         1
# 4       3    0  29.5   8.05         0
